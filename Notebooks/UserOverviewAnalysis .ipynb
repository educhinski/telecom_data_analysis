# %%
import numpy as np
import pandas as pd

# %%
CSV_PATH = "../data/data.csv"

# %%
#setting our columns to display full values
import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_column', None)

# %%
def read_csv(csv_path):
    try:    
        df = pd.read_csv(csv_path)
        print("file read as csv")
        return df
    except FileNotFoundError:
        print("file not found")

# %%
df = read_csv(CSV_PATH)
# Out:
# file read as csv

# %%
df.head()
# Out:
#                       Bearer Id            Start             Start ms  \
# 0 13,114,483,460,844,900,352.00   4/4/2019 12:01               770.00
# 1 13,114,483,482,878,900,224.00   4/9/2019 13:04               235.00
# 2 13,114,483,484,080,500,736.00   4/9/2019 17:42                 1.00
# 3 13,114,483,485,442,799,616.00   4/10/2019 0:31               486.00
# 4 13,114,483,499,480,700,928.00  4/12/2019 20:10               565.00
#
#                End               End ms            Dur. (ms)  \
# 0  4/25/2019 14:35               662.00         1,823,652.00
# 1   4/25/2019 8:15               606.00         1,365,104.00
# 2  4/25/2019 11:58               652.00         1,361,762.00
# 3   4/25/2019 7:36               171.00         1,321,509.00
# 4  4/25/2019 10:40               954.00         1,089,009.00
#
#                     IMSI        MSISDN/Number                  IMEI  \
# 0 208,201,448,079,117.00    33,664,962,239.00 35,521,209,507,511.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 149010 non-null  float64
#  1   Start                                     150000 non-null  object
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  object
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
#  9   Last Location Name                        148848 non-null  object
# ...

# %%
df.shape
# Out:
# (150001, 55)

# %%
df.isnull().sum()
# Out:
# Bearer Id                                      991
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# ...

# %%
def percent_missing(df):

    totalCells = np.product(df.shape)
    missingCount = df.isnull().sum()
    totalMissing = missingCount.sum()
    return round((totalMissing / totalCells) * 100, 2)

# %%
percent_missing(df)
# Out:
# 12.5

# %%
def percent_missing_for_col(df, col_name: str):
    total_count = len(df[col_name])
    if total_count <= 0:
        return 0.0
    missing_count = df[col_name].isnull().sum()
    
    return round((missing_count / total_count) * 100, 2)

# %%
null_percent_df = pd.DataFrame(columns = ['column', 'null_percent'])
columns = df.columns.values.tolist()
null_percent_df['column'] = columns
null_percent_df['null_percent'] = null_percent_df['column'].map(lambda x: percent_missing_for_col(df, x))

# %%
null_percent_df.sort_values(by=['null_percent'], ascending = False)
# Out:
#                                       column         null_percent
# 34            Nb of sec with 37500B < Vol UL                86.84
# 36    Nb of sec with 6250B < Vol UL < 37500B                74.56
# 31           Nb of sec with 125000B < Vol DL                65.02
# 15               TCP UL Retrans. Vol (Bytes)                64.43
# 33  Nb of sec with 31250B < Vol DL < 125000B                62.39
# 32     Nb of sec with 1250B < Vol UL < 6250B                61.93
# 35    Nb of sec with 6250B < Vol DL < 31250B                58.88
# 14               TCP DL Retrans. Vol (Bytes)                58.76
# 25                           HTTP UL (Bytes)                54.54
# 24                           HTTP DL (Bytes)                54.32
# 10                           Avg RTT DL (ms)                18.55
# 11                           Avg RTT UL (ms)                18.54
# 9                         Last Location Name                 0.77
# ...

# %%
def drop_columns(df, columns=[]):
    return df.drop(columns, axis=1)

# %%
columns_to_be_dropped = null_percent_df[null_percent_df['null_percent'] > 30]['column'].to_list()
df = drop_columns(df, columns_to_be_dropped)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Bearer Id                       149010 non-null  float64
#  1   Start                           150000 non-null  object
#  2   Start ms                        150000 non-null  float64
#  3   End                             150000 non-null  object
#  4   End ms                          150000 non-null  float64
#  5   Dur. (ms)                       150000 non-null  float64
#  6   IMSI                            149431 non-null  float64
#  7   MSISDN/Number                   148935 non-null  float64
#  8   IMEI                            149429 non-null  float64
#  9   Last Location Name              148848 non-null  object
#  10  Avg RTT DL (ms)                 122172 non-null  float64
# ...

# %%
df.columns = [column.replace(' ', '_').lower() for column in df.columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   bearer_id                       149010 non-null  float64
#  1   start                           150000 non-null  object
#  2   start_ms                        150000 non-null  float64
#  3   end                             150000 non-null  object
#  4   end_ms                          150000 non-null  float64
#  5   dur._(ms)                       150000 non-null  float64
#  6   imsi                            149431 non-null  float64
#  7   msisdn/number                   148935 non-null  float64
#  8   imei                            149429 non-null  float64
#  9   last_location_name              148848 non-null  object
#  10  avg_rtt_dl_(ms)                 122172 non-null  float64
# ...

# %%
percent_missing(df)
# Out:
# 1.02

# %%
df['last_location_name'].isnull().sum()
df['handset_manufacturer'].isnull().sum()
df['handset_type'].isnull().sum()
df['start'].isnull().sum()
# Out:
# 1
